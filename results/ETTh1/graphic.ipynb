# %% [markdown]
# # Results to ETTh1

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Functions

# %%
def multilabel_barplot(categories:list, values:dict, ylabel, title):
    """
    Example:
    categories = ("Adelie", "Chinstrap", "Gentoo")
    values = {
        'Bill Depth': (18.35, 18.43, 14.98),
        'Bill Length': (38.79, 48.83, 47.50),
        'Flipper Length': (189.95, 195.82, 217.19),
    }"""
    x = np.arange(len(categories))  # the label locations
    width = 0.75/len(values.keys())  # the width of the bars
    multiplier = 0

    fig, ax = plt.subplots(layout='constrained')

    for attribute, measurement in values.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, measurement, width, label=attribute)
        #ax.bar_label(rects, padding=3)
        multiplier += 1

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    ax.set_xticks(x + width, categories, rotation = 45)
    ax.legend(loc='upper right', ncols=3)
    ax.grid()
    #ax.set_ylim(0, 250)
    #plt.grid
    plt.show()

# %% [markdown]
# ## 24 hours

# %% [markdown]
# ### Data

# %%
data = {
    "KAN": {
        "results" : {
            "Train" : 5.0139,
            "Test" : 3.669,
            "Validation" : 6.1903791427612305,
            "Time" : np.mean([25384.145509958267, 
                              25702.146057844162,
                              25735.563086509705,
                              25678.495260238647]),
            "Epochs" : 3
        },
        "models" : {
            "KAN" : {
                "Train" : 11.9553,
                "Test" : 3.8982,
                "Validation" : 6.538564682006836,
                "Time" : 2998.29802274704,
                "Epochs" : 1
            },
            "Elman" : {
                "Train" : 53.5450,
                "Test" : 49.3304,
                "Validation" : 49.51327896118164,
                "Time" : 1226.3748035430908,
                "Epochs" :7
            }, 
            "GRU" : {
                "Train" : 29.6373,
                "Test" : 2.7648,
                "Validation" : 3.396848440170288,
                "Time" : 1832.7121119499207,
                "Epochs" : 19
            }, 
            "LSTM" : {
                "Train" : 24.6954,
                "Test" : 2.0394,
                "Validation" : 2.2025442123413086,
                "Time" : 5505.88249874115,
                "Epochs" : 97
            }
        }
    }, 
    "Elman": {
        "results" : {
            "Train" : 3.2262,
            "Test" : 1.9071,
            "Validation" : 3.6317031383514404,
            "Time" : 94546.92758870125,
            "Epochs" : 539
        },
        "models" : {
            "KAN" : {
                "Train" : None,
                "Test" : None,
                "Validation" : None,
                "Time" : None,
                "Epochs" :None
            },
            "Elman" : {
                "Train" : None,
                "Test" : None,
                "Validation" : None,
                "Time" : None,
                "Epochs" :None
            }, 
            "GRU" : {
                "Train" : None,
                "Test" : None,
                "Validation" : None,
                "Time" : None,
                "Epochs" : None
            }, 
            "LSTM" : {
                "Train" : 3.2365,
                "Test" : 1.9137,
                "Validation" : 3.6398959159851074,
                "Time" : 530.9518558979034,
                "Epochs" : 6
            }
        }
    }, 
    "GRU": {
        "results" : {
            "Train" : 3.8305,
            "Test" : 2.8623,
            "Validation" : 3.7878050804138184,
            "Time" :  np.mean([33037.984364748,
                               33575.908276081085,
                               33043.780709028244,
                               33037.314412117004
                               ]),
            "Epochs" : 64
        },
        "models" : {
            "KAN" : {
                "Train" : 6.2105,
                "Test" : 2.8871,
                "Validation" : 4.378207683563232,
                "Time" : 7047.396971940994,
                "Epochs" : 29
            },
            "Elman" : {
                "Train" : 47.5519,
                "Test" : 48.8168,
                "Validation" : 49.632015228271484,
                "Time" : 1228.4880588054657,
                "Epochs" : 6
            }, 
            "GRU" : {
                "Train" : 3.2587,
                "Test" : 2.5673,
                "Validation" : 3.483104944229126,
                "Time" : 2682.6971185207367,
                "Epochs" : 36
            }, 
            "LSTM" : {
                "Train" : 2.8205,
                "Test" : 2.3196,
                "Validation" : 3.038595676422119,
                "Time" : 9730.50150680542,
                "Epochs" : 185
            }
        },
    }, 
    "LSTM": {
        "results" : {
            "Train" : 3.0094,
            "Test" : 2.4647,
            "Validation" : 4.92582893371582,
            "Time" :  np.mean([36421.63827037811,
                               36549.98110342026,
                               36472.58390927315,
                               36066.22600388527]),
            "Epochs" : 73
        },
        "models" : {
            "KAN" : {
                "Train" : 4.0912,
                "Test" : 2.4794,
                "Validation" : 4.987544059753418,
                "Time" : 5762.278369903564,
                "Epochs" : 20
            },
            "Elman" : {
                "Train" : 49.3218,
                "Test" : 49.3136,
                "Validation" : 49.2074089050293,
                "Time" : 1098.887132883072,
                "Epochs" : 3
            }, 
            "GRU" : {
                "Train" : 3.2439,
                "Test" : 2.2693,
                "Validation" : 4.8473429679870605,
                "Time" : 1435.7399179935455,
                "Epochs" : 10
            }, 
            "LSTM" : {
                "Train" : 3.1180,
                "Test" : 2.3091,
                "Validation" : 4.813722133636475,
                "Time" : 1579.7802205085754,
                "Epochs" : 14
            }
        }
    }
}

# %% [markdown]
# ### Results for base models

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = data.keys(), 
                   values = {key: [data[model]["results"][key] for model in data.keys()] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Global

# %%
plt.bar(data.keys(), [data[model]["results"]["Time"] for model in data.keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[model]["results"]["Epochs"] for model in data.keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[model]["results"]["Time"] for model in data.keys()]) / np.array([data[model]["results"]["Epochs"] for model in data.keys()]))
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Results for KANs

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["KAN-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["KAN"]["results"][key]]+[data["KAN"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for KAN models")

# %%
multilabel_barplot(categories = ["base"]+["KAN-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["KAN"]["results"][key]]+[data["KAN"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in [ "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "KAN"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Results for Elman

# %% [markdown]
# ### Results for GRU

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["GRU-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["GRU"]["results"][key]]+[data["GRU"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "GRU"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Results for LSTM

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["LSTM-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["LSTM"]["results"][key]]+[data["LSTM"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "LSTM"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Best models

# %% [markdown]
# #### Precision

# %%
models = [("KAN", "LSTM"), ("GRU", "LSTM"), ("KAN", "GRU"), ("GRU", "GRU"), ("GRU", )]
multilabel_barplot(categories = [f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models],
                   values = {key : [data[mod[0]]["models"][mod[1]][key]  if len(mod)>1 else data[mod[0]]["results"][key] for mod in models] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %%
multilabel_barplot(categories = [f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models],
                   values = {key : [data[mod[0]]["models"][mod[1]][key]  if len(mod)>1 else data[mod[0]]["results"][key] for mod in models] for key in ["Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Time

# %%
plt.bar([f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models], 
        [data[mod[0]]["models"][mod[1]]["Time"]  if len(mod)>1 else data[mod[0]]["results"]["Time"] for mod in models])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ## 48 hours

# %% [markdown]
# ### Data

# %%
data = {
    "KAN": {
        "results" : {
            "Train" : 5.2218,
            "Test" : 4.7014,
            "Validation" : 7.805968284606934,
            "Time" : np.mean([26384.633150815964, 
                              26818.234810829163,
                              26798.66692996025,
                              26799.50930094719]),
            "Epochs" : 1
        },
        "models" : {
            "KAN" : {
                "Train" : 10.0769,
                "Test" : 4.6241,
                "Validation" : 4.969145774841309,
                "Time" : 15559.133918523788,
                "Epochs" : 24
            },
            "Elman" : {
                "Train" : 4.9864,
                "Test" : 2.6351,
                "Validation" : 2.401719331741333,
                "Time" : 14209.673442363739,
                "Epochs" : 67
            }, 
            "GRU" : {
                "Train" : 29.6373,
                "Test" : 2.4054,
                "Validation" : 2.863588809967041,
                "Time" : 31294.597776174545,
                "Epochs" : 170
            }, 
            "LSTM" : {
                "Train" : 5.5391,
                "Test" : 2.5001,
                "Validation" : 2.7770237922668457,
                "Time" : 10829.605744600296,
                "Epochs" : 45
            }
        }
    }, 
    "Elman": {
        "results" : {
            "Train" : 4.2771,
            "Test" : 2.3448,
            "Validation" : 4.125314712524414,
            "Time" : np.mean([59524.61197733879,
                              59233.01333427429,
                              ]),
            "Epochs" : 331
        },
        "models" : {
            "KAN" : {
                "Train" : 4.3375,
                "Test" : 2.3695,
                "Validation" : 4.332584381103516,
                "Time" : 7238.529736042023,
                "Epochs" :26
            },
            "Elman" : {
                "Train" : 48.1987,
                "Test" : 49.8596,
                "Validation" : 49.787132263183594,
                "Time" : 1511.7469699382782,
                "Epochs" : 1
            }, 
            "GRU" : {
                "Train" : 3.8093,
                "Test" : 2.8529,
                "Validation" : 4.043943405151367,
                "Time" : 5593.569318771362,
                "Epochs" : 14
            }, 
            "LSTM" : {
                "Train" : 4.7451,
                "Test" : 2.9856,
                "Validation" : 3.8800950050354004,
                "Time" : 5069.4467487335205,
                "Epochs" : 11
            }
        }
    }, 
    "GRU": {
        "results" : {
            "Train" : 6.6488,
            "Test" : 3.5370,
            "Validation" : 5.908991813659668,
            "Time" :  np.mean([29271.93669295311,
                               28494.096719503403,
                               28594.310040712357,
                               28728.715111017227,
                               ]),
            "Epochs" : 53
        },
        "models" : {
            "KAN" : {
                "Train" : 5.1000,
                "Test" : 3.3827,
                "Validation" : 5.0810723304748535,
                "Time" : 13053.20071554184,
                "Epochs" : 16
            },
            "Elman" : {
                "Train" : 49.2321,
                "Test" : 49.5916,
                "Validation" : 50.18878936767578,
                "Time" : 9357.864661693573,
                "Epochs" : 36
            }, 
            "GRU" : {
                "Train" : 4.8505,
                "Test" : 3.2749,
                "Validation" : 5.399015426635742,
                "Time" : 6545.770563364029,
                "Epochs" : 19
            }, 
            "LSTM" : {
                "Train" : 3.3436,
                "Test" : 2.9833,
                "Validation" : 4.616207599639893,
                "Time" : 19140.35465979576,
                "Epochs" : 185
            }
        },
    }, 
    "LSTM": {
        "results" : {
            "Train" : 3.7002,
            "Test" : 3.0010,
            "Validation" : 6.003325939178467,
            "Time" :  np.mean([33312.56008529663,
                               33042.95852684975,
                               14227.944654226303,
                               14209.454369544983]),
            "Epochs" : 64
        },
        "models" : {
            "KAN" : {
                "Train" : 4.0888,
                "Test" : 3.0836,
                "Validation" : 7.449317932128906,
                "Time" : 7621.004998445511,
                "Epochs" : 1
            },
            "Elman" : {
                "Train" : 48.1186,
                "Test" : 48.2604,
                "Validation" : 49.73788833618164,
                "Time" : 5190.923305511475,
                "Epochs" : 11
            }, 
            "GRU" : {
                "Train" : 5.4118,
                "Test" : 2.8850,
                "Validation" : 6.0369873046875,
                "Time" : 1676.6357243061066,
                "Epochs" : 3
            }, 
            "LSTM" : {
                "Train" : 3.5688,
                "Test" : 2.7999,
                "Validation" : 5.686861991882324,
                "Time" : 2598.5646233558655,
                "Epochs" : 16
            }
        }
    }
}

# %% [markdown]
# ### Results for base models

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = data.keys(), 
                   values = {key: [data[model]["results"][key] for model in data.keys()] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Global

# %%
plt.bar(data.keys(), [data[model]["results"]["Time"] for model in data.keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[model]["results"]["Epochs"] for model in data.keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[model]["results"]["Time"] for model in data.keys()]) / np.array([data[model]["results"]["Epochs"] for model in data.keys()]))
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Results for KANs

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["KAN-"+ model for model in ["KAN", "Elman", "GRU", "LSTM"]],
                   values = {key : [data["KAN"]["results"][key]]+[data["KAN"]["models"][model][key] for model in ["KAN", "Elman", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for KAN models")

# %%
multilabel_barplot(categories = ["base"]+["KAN-"+ model for model in ["KAN", "Elman", "GRU", "LSTM"]],
                   values = {key : [data["KAN"]["results"][key]]+[data["KAN"]["models"][model][key] for model in ["KAN", "Elman", "GRU", "LSTM"]] for key in [ "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "KAN"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Elman

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["Elman"]+["Elman-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["Elman"]["results"][key]]+[data["Elman"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "Elman"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### GRU

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["GRU-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["GRU"]["results"][key]]+[data["GRU"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "GRU"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### LSTM

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["LSTM-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["LSTM"]["results"][key]]+[data["LSTM"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "LSTM"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Best models

# %% [markdown]
# #### Precision

# %%
models = [("KAN", "Elman"), ("KAN","LSTM"), ("KAN", "GRU"), ("Elman", "LSTM"), ("Elman", "GRU")]
multilabel_barplot(categories = [f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models],
                   values = {key : [data[mod[0]]["models"][mod[1]][key]  if len(mod)>1 else data[mod[0]]["results"][key] for mod in models] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %%
multilabel_barplot(categories = [f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models],
                   values = {key : [data[mod[0]]["models"][mod[1]][key]  if len(mod)>1 else data[mod[0]]["results"][key] for mod in models] for key in ["Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Time

# %%
plt.bar([f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models], 
        [data[mod[0]]["models"][mod[1]]["Time"]  if len(mod)>1 else data[mod[0]]["results"]["Time"] for mod in models])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ## 168 hours

# %% [markdown]
# ### Data

# %%
data = {
    "KAN": {
        "results" : {
            "Train" : 8.3604,
            "Test" : 3.4824,
            "Validation" : 5.019408702850342,
            "Time" : np.mean([41805.32020282745,
                              41886.75821518898,
                              ]),
            "Epochs" : 24
        },
        "models" : {
            "KAN" : {
                "Train" : 8.5424,
                "Test" : 4.3343,
                "Validation" : 5.6047797203063965,
                "Time" : 110794.21600008011,
                "Epochs" : 23
            },
            "Elman" : {
                "Train" : 46.4015,
                "Test" : 49.7214,
                "Validation" : 48.877742767333984,
                "Time" : 16598.88840985298,
                "Epochs" : 1
            }, 
            "GRU" : {
                "Train" : 3.8316,
                "Test" : 3.1127,
                "Validation" : 2.7415082454681396,
                "Time" : 90162.80839276314,
                "Epochs" : 96
            }, 
            "LSTM" : {
                "Train" : 5.4229,
                "Test" : 3.3995,
                "Validation" : 4.43438720703125,
                "Time" : 83871.67987322807,
                "Epochs" : 45
            }
        }
    }, 
    "Elman": {
        "results" : {
            "Train" : 4.8955,
            "Test" : 3.0701,
            "Validation" : 5.123001575469971,
            "Time" : np.mean([40115.752477645874,
                              40244.48233985901,
                              40316.49285244942,
                              17325.4606859684
                              ]),
            "Epochs" : 82
        },
        "models" : {
            "KAN" : {
                "Train" : 5.6390,
                "Test" : 3.1488,
                "Validation" : 5.148768424987793,
                "Time" : 109010.71365475655,
                "Epochs" : 23
            },
            "Elman" : {
                "Train" : 50.8890,
                "Test" : 50.0434,
                "Validation" : 50.39318084716797,
                "Time" : 77875.5253663063,
                "Epochs" : 21
            }, 
            "GRU" : {
                "Train" : 12.4292,
                "Test" : 5.8693,
                "Validation" : 9.230770111083984,
                "Time" : 44394.42256164551,
                "Epochs" : 4
            }, 
            "LSTM" : {
                "Train" : 8.1748,
                "Test" : 3.1567,
                "Validation" : 5.516846179962158,
                "Time" : 25292.31963968277,
                "Epochs" : 11
            }
        }
    }, 
    "GRU": {
        "results" : {
            "Train" : 3.9064,
            "Test" : 3.2987,
            "Validation" : 4.435059547424316,
            "Time" :  np.mean([30585.720812559128,
                               29163.533488988876,
                               29406.837304353714,
                               29273.061980724335]),
            "Epochs" : 151
        },
        "models" : {
            "KAN" : {
                "Train" : 5.8908,
                "Test" : 3.3692,
                "Validation" : 4.131884574890137,
                "Time" : 42709.01511454582,
                "Epochs" : 18
            },
            "Elman" : {
                "Train" : 49.0675,
                "Test" : 49.8629,
                "Validation" : 49.562294006347656,
                "Time" : 22461.03516435623,
                "Epochs" : 36
            }, 
            "GRU" : {
                "Train" : 4.4492,
                "Test" : 3.3089,
                "Validation" : 3.7343971729278564,
                "Time" : 32408.28817176819,
                "Epochs" : 21
            }, 
            "LSTM" : {
                "Train" : 4.5230,
                "Test" : 3.2840,
                "Validation" : 3.8366169929504395,
                "Time" : 30741.14455294609,
                "Epochs" : 20
            }
        },
    }, 
    "LSTM": {
        "results" : {
            "Train" : 3.7786,
            "Test" : 3.2283,
            "Validation" : 4.915536880493164,
            "Time" :  np.mean([27267.872168540955,
                               27320.32344675064,
                               63323.900478601456]),
            "Epochs" : 140
        },
        "models" : {
            "KAN" : {
                "Train" : 6.2049,
                "Test" : 3.1518,
                "Validation" : 5.069074630737305,
                "Time" : 45414.879371881485,
                "Epochs" : 21
            },
            "Elman" : {
                "Train" : 48.0283,
                "Test" : 49.0304,
                "Validation" : 49.407432556152344,
                "Time" : 16749.39415860176,
                "Epochs" : 1
            }, 
            "GRU" : {
                "Train" : 4.1741,
                "Test" : 3.2612,
                "Validation" : 4.704379081726074,
                "Time" : 98321.56040167809,
                "Epochs" : 33
            }, 
            "LSTM" : {
                "Train" : 4.4034,
                "Test" : 3.2650,
                "Validation" : 4.832955360412598,
                "Time" : 77049.1697010994,
                "Epochs" : 21
            }
        }
    }
}

# %% [markdown]
# ### Results for base models

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = data.keys(), 
                   values = {key: [data[model]["results"][key] for model in data.keys()] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Global

# %%
plt.bar(data.keys(), [data[model]["results"]["Time"] for model in data.keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[model]["results"]["Epochs"] for model in data.keys()])
plt.ylabel("Epochs")
plt.title("Average training epochs for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[model]["results"]["Time"] for model in data.keys()]) / np.array([data[model]["results"]["Epochs"] for model in data.keys()]))
plt.ylabel("Time")
plt.title("Average training time fr each epoch for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Results for KANs

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["KAN-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["KAN"]["results"][key]]+[data["KAN"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for KAN models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "KAN"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Elman

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["Elman"]+["Elman-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["Elman"]["results"][key]]+[data["Elman"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "Elman"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### GRU

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["GRU-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["GRU"]["results"][key]]+[data["GRU"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "GRU"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### LSTM

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["LSTM-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["LSTM"]["results"][key]]+[data["LSTM"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "LSTM"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Best models

# %% [markdown]
# #### Precision

# %%
models = [("KAN", "GRU"), ("GRU", "GRU"), ("GRU", "LSTM"), ("GRU", "KAN"), ("GRU",) ]
multilabel_barplot(categories = [f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models],
                   values = {key : [data[mod[0]]["models"][mod[1]][key]  if len(mod)>1 else data[mod[0]]["results"][key] for mod in models] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Time

# %%
plt.bar([f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models], 
        [data[mod[0]]["models"][mod[1]]["Time"]  if len(mod)>1 else data[mod[0]]["results"]["Time"] for mod in models])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ## 336 hours

# %% [markdown]
# ### Data

# %%
data = {
    "KAN": {
        "results" : {
            "Train" : 5.3924,
            "Test" : 4.5579,
            "Validation" : 7.574666500091553,
            "Time" : np.mean([93890.69813513756,
                              93518.9853849411,
                              92487.11345028877,
                              ]),
            "Epochs" : 9
        },
        "models" : {
            "KAN" : {
                "Train" : 4.9706,
                "Test" : 4.8184,
                "Validation" : 7.328705310821533,
                "Time" : 243820.73377871513,
                "Epochs" : 8
            },
            "Elman" : {
                "Train" : None,
                "Test" : None,
                "Validation" : None,
                "Time" : None,
                "Epochs" : None
            }, 
            "GRU" : {
                "Train" : 18.2327,
                "Test" : 4.6349,
                "Validation" : 7.78389310836792,
                "Time" : 158024.90669250488,
                "Epochs" : 2
            }, 
            "LSTM" : {
                "Train" : 10.6275,
                "Test" : 4.1568,
                "Validation" : 6.428549766540527,
                "Time" : 328867.22041893005,
                "Epochs" : 26
            }
        }
    }, 
    "Elman": {
        "results" : {
            "Train" : 5.8294,
            "Test" : 5.1869,
            "Validation" : 7.710124492645264,
            "Time" : np.mean([31529.02798628807,
                              31565.986493825912,
                              31409.114389896393,
                              32063.317918777466]),
            "Epochs" : 59
        },
        "models" : {
            "KAN" : {
                "Train" : 4.5758,
                "Test" : 4.8337,
                "Validation" : 8.465911865234375,
                "Time" : 233836.72808241844,
                "Epochs" : 8
            },
            "Elman" : {
                "Train" : 49.8144,
                "Test" : 49.2718,
                "Validation" : 50.10445785522461,
                "Time" : 154092.1076233387,
                "Epochs" : 2
            }, 
            "GRU" : {
                "Train" : 31.9448,
                "Test" : 34.6699,
                "Validation" : 37.42072677612305,
                "Time" : 151062.83073592186,
                "Epochs" : 1
            }, 
            "LSTM" : {
                "Train" : 8.3978,
                "Test" : 5.2323,
                "Validation" : 8.50664234161377,
                "Time" : 148373.89224290848,
                "Epochs" : 1
            }
        }
    }, 
    "GRU": {
        "results" : {
            "Train" : 11.9607,
            "Test" : 8.9486,
            "Validation" : 17.079111099243164,
            "Time" :  np.mean([21153.60978269577,
                               20977.250852823257,
                               9375.285393476486,
                               9375.267325162888]),
            "Epochs" : 32
        },
        "models" : {
            "KAN" : {
                "Train" : 5.4306,
                "Test" : 10.0883,
                "Validation" : 17.867076873779297,
                "Time" : 232396.3817205429,
                "Epochs" : 8
            },
            "Elman" : {
                "Train" : 51.4942,
                "Test" : 49.7059,
                "Validation" : 51.8594856262207,
                "Time" : 157138.76469755173,
                "Epochs" : 2
            }, 
            "GRU" : {
                "Train" : 13.7666,
                "Test" : 9.5255,
                "Validation" : 13.714323043823242,
                "Time" : 171139.4825541973,
                "Epochs" : 35
            }, 
            "LSTM" : {
                "Train" : 11.4019,
                "Test" : 9.7283,
                "Validation" : 16.153223037719727,
                "Time" : 92032.47845244408,
                "Epochs" : 11
            }
        },
    }, 
    "LSTM": {
        "results" : {
            "Train" : 4.0419,
            "Test" : 3.7281,
            "Validation" : 4.979859352111816,
            "Time" :  np.mean([28441.84178876877,
                               28509.372119903564,
                               28187.168920993805,
                               28223.60089993477]),
            "Epochs" : 141
        },
        "models" : {
            "KAN" : {
                "Train" : 4.0283,
                "Test" : 4.2544,
                "Validation" : 5.001715660095215,
                "Time" : 102785.31848812103,
                "Epochs" : 8
            },
            "Elman" : {
                "Train" : 48.4100,
                "Test" : 49.4668,
                "Validation" : 50.009220123291016,
                "Time" : 64863.22671747208,
                "Epochs" : 1
            }, 
            "GRU" : {
                "Train" : 8.4036,
                "Test" : 4.4899,
                "Validation" : 6.373797416687012,
                "Time" : 64414.064593076706,
                "Epochs" : 1
            }, 
            "LSTM" : {
                "Train" : 4.5626,
                "Test" : 4.3401,
                "Validation" : 5.528921604156494,
                "Time" : 157423.82651686668,
                "Epochs" : 32
            }
        }
    }
}

# %% [markdown]
# ### Results for base models

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = data.keys(), 
                   values = {key: [data[model]["results"][key] for model in data.keys()] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Global

# %%
plt.bar(data.keys(), [data[model]["results"]["Time"] for model in data.keys()])
plt.ylabel("Time")
plt.title("Average training time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[model]["results"]["Epochs"] for model in data.keys()])
plt.ylabel("Epochs")
plt.title("Average training epochs for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[model]["results"]["Time"] for model in data.keys()]) / np.array([data[model]["results"]["Epochs"] for model in data.keys()]))
plt.ylabel("Time")
plt.title("Average training time fr each epoch for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Results for KANs

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["KAN-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["KAN"]["results"][key]]+[data["KAN"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for KAN models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "KAN"
plt.bar(["KAN", "GRU", "LSTM"], [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in ["KAN", "GRU", "LSTM"]])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(["KAN", "GRU", "LSTM"], [data[base]["models"][model]["Time"] for model in ["KAN", "GRU", "LSTM"]])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(["KAN", "GRU", "LSTM"], [data[base]["models"][model]["Epochs"] for model in ["KAN", "GRU", "LSTM"]])
plt.ylabel("Time")
plt.title("Average training epochs for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(["KAN", "GRU", "LSTM"], np.array([data[base]["models"][model]["Time"] for model in ["KAN", "GRU", "LSTM"]]) / np.array([data[base]["models"][model]["Epochs"] for model in ["KAN", "GRU", "LSTM"]]))
plt.ylabel("Time")
plt.title("Average training by epoch time for autorregressive models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Elman

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["Elman"]+["Elman-"+ model for model in ["KAN", "LSTM"]],
                   values = {key : [data["Elman"]["results"][key]]+[data["Elman"]["models"][model][key] for model in ["KAN", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "Elman"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### GRU

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["GRU-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["GRU"]["results"][key]]+[data["GRU"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "GRU"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### LSTM

# %% [markdown]
# #### Precision

# %%
multilabel_barplot(categories = ["base"]+["LSTM-"+ model for model in ["KAN", "GRU", "LSTM"]],
                   values = {key : [data["LSTM"]["results"][key]]+[data["LSTM"]["models"][model][key] for model in ["KAN", "GRU", "LSTM"]] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Times

# %% [markdown]
# ##### Total

# %%
base = "LSTM"
plt.bar(data.keys(), [data[base]["results"]["Time"]+data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Partial

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Time"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training time for error regression.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Epochs

# %%
plt.bar(data.keys(), [data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()])
plt.ylabel("Time")
plt.title("Average training epochs for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ##### Time / epoch

# %%
plt.bar(data.keys(), np.array([data[base]["models"][model]["Time"] for model in data[base]["models"].keys()]) / np.array([data[base]["models"][model]["Epochs"] for model in data[base]["models"].keys()]))
plt.ylabel("Time")
plt.title("Average training time by epoch for error regression models.")
plt.grid()
plt.show()

# %% [markdown]
# ### Best models

# %% [markdown]
# #### Precision

# %%
models = [("LSTM", ), ("LSTM", "KAN"), ("KAN", "LSTM"), ("KAN", "KAN"), ("KAN", )]
multilabel_barplot(categories = [f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models],
                   values = {key : [data[mod[0]]["models"][mod[1]][key]  if len(mod)>1 else data[mod[0]]["results"][key] for mod in models] for key in ["Train", "Test", "Validation"]},
                   ylabel="RMSE",
                   title="Results for base models")

# %% [markdown]
# #### Time

# %%
plt.bar([f"{mod[0]}-{mod[1]}" if len(mod)>1 else mod[0] for mod in models], 
        [data[mod[0]]["models"][mod[1]]["Time"]  if len(mod)>1 else data[mod[0]]["results"]["Time"] for mod in models])
plt.ylabel("Time")
plt.title("Total average training time.")
plt.grid()
plt.show()
